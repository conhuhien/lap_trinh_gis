# %%
#Câu 1
# %matplotlib inline

import pandas as pd
import geopandas

pd.options.display.max_rows = 20

# %%
#câu 2
rivers = geopandas.read_file("zip://./data/ne_50m_rivers_lake_centerlines.zip")

# %%
#Câu 3
rivers.head(15)
# Out:
#     scalerank       featurecla           name  note  min_zoom name_alt  \
# 0           6  Lake Centerline           Kama  None       5.0     None
# 1           6            River           Kama  None       5.0     None
# 2           3  Lake Centerline           Abay  None       3.0     None
# 3           3  Lake Centerline       Al Furat  None       3.0     None
# 4           6  Lake Centerline        Alabama  None       5.0     None
# 5           6  Lake Centerline         Albany  None       5.0     None
# 6           1  Lake Centerline    Albert Nile  None       2.0     None
# 7           3  Lake Centerline           Amur  None       3.0     None
# 8           2  Lake Centerline         Angara  None       2.1     None
# 9           6  Lake Centerline         Atbara  None       5.0     None
# 10          5  Lake Centerline      Athabasca  None       4.7     None
# 11          6  Lake Centerline           Back  None       5.0     None
# 12          6  Lake Centerline           Biya  None       5.0     None
# 13          6  Lake Centerline  Chattahoochee  None       5.0     None
# 14          6  Lake Centerline      Churchill  None       5.0     None
#
#           name_en  min_label  \
# 0            Kama        6.0
# 1            Kama        6.0
# 2            Abay        4.0
# 3        Al Furat        4.0
# 4         Alabama        6.0
# 5          Albany        6.0
# 6     Albert Nile        3.0
# 7            Amur        4.0
# 8          Angara        3.1
# 9          Atbara        6.0
# 10      Athabasca        5.7
# 11           Back        6.0
# 12           Biya        6.0
# 13  Chattahoochee        6.0
# 14      Churchill        6.0
#
#                                              geometry
# 0   LINESTRING (51.9371337598152 55.70106609892139...
# 1   LINESTRING (53.69384765584471 58.2063174502901...
# 2   LINESTRING (37.11301150887408 11.8549872909308...
# 3   LINESTRING (38.56119184742585 35.8626433379197...
# 4   (LINESTRING (-86.52176754393696 33.03211843501...
# 5   (LINESTRING (-91.31225033198717 51.06272329324...
# 6   LINESTRING (31.36669559132855 2.19335480348144...
# 7   (LINESTRING (137.0699076685041 50.454078274392...
# 8   (LINESTRING (106.4973035010558 52.383107815173...
# 9   LINESTRING (35.92414350751693 14.9353677433267...
# 10  (LINESTRING (-111.0155696273364 58.69099152314...
# 11  (LINESTRING (-108.533318040695 64.562080186251...
# 12  LINESTRING (87.75570844948544 51.3643844672694...
# 13  (LINESTRING (-84.96633277034107 30.92263479236...
# 14  LINESTRING (-64.68224789102732 53.125181382514...

# %%
#Câu 4
rivers.plot()

# %%
#Câu 5
rivers.geometry
# Out:
# 0      LINESTRING (51.9371337598152 55.70106609892139...
# 1      LINESTRING (53.69384765584471 58.2063174502901...
# 2      LINESTRING (37.11301150887408 11.8549872909308...
# 3      LINESTRING (38.56119184742585 35.8626433379197...
# 4      (LINESTRING (-86.52176754393696 33.03211843501...
#                              ...
# 457    (LINESTRING (106.4640238791987 10.298312282985...
# 458    LINESTRING (-101.1627601793388 62.366684474908...
# 459    LINESTRING (1.454465486420069 43.4152701040649...
# 460                                                 None
# 461    (LINESTRING (3.083254022055542 46.985426947295...
# Name: geometry, Length: 462, dtype: object

# %%
#Câu 6
rivers.length
# Out:
# 0       2.864469
# 1      16.814525
# 2       0.470762
# 3       0.848945
# 4       0.430752
#          ...
# 457     1.222592
# 458     0.157126
# 459     2.810315
# 460          NaN
# 461     8.849704
# Length: 462, dtype: float64

# %%
#Câu 7
rivers['scalerank'].mean()
# Out:
# 4.5995670995671

# %%
#Câu 8
kama = rivers[rivers['name'] == 'Kama']
kama.plot()

# %%
#Câu 9
abay = rivers[rivers['name'] == 'Abay']
abay.length.mean()
# Out:
# 2.41955305338252

# %%
#Câu 10
rivers.crs
# Out:
# {'init': 'epsg:4326'}

# %%
#Câu 11
import statistics

# %%
#Câu 12
statistics.mean([11,2,13,14,44])
# Out:
# 16.8

# %%
#Câu 13
import pandas as pd
import geopandas as gpd

# %%
#Câu 14
df = gpd.read_file("data/berlin-districts.geojson")

# %%
#Câu 15
df.head(10)
# Out:
#                                     district            district_group  \
# 0             Blankenfelde/Niederschönhausen                    Pankow
# 1                             Helmholtzplatz                    Pankow
# 2                         Wiesbadener Straße      Charlottenburg-Wilm.
# 3  Schmöckwitz/Karolinenhof/Rauchfangswerder        Treptow - Köpenick
# 4                                 Müggelheim        Treptow - Köpenick
# 5                                   Biesdorf     Marzahn - Hellersdorf
# 6                                     Nord 1             Reinickendorf
# 7                                     West 5             Reinickendorf
# 8                     Frankfurter Allee Nord  Friedrichshain-Kreuzberg
# 9                                       Buch                    Pankow
#
#    median_price                                           geometry
# 0          37.5  (POLYGON ((1493006.880445722 6912074.798336806...
# 1          58.0  (POLYGON ((1493245.549433984 6900059.69597819,...
# 2          50.0  (POLYGON ((1481381.45206371 6885170.697768607,...
# 3          99.0  (POLYGON ((1526159.828554794 6872101.043604896...
# 4          25.0  (POLYGON ((1529265.085750472 6874326.842288786...
# 5          35.0  (POLYGON ((1510208.413441061 6897463.302167942...
# 6          31.0  (POLYGON ((1484633.094389781 6913501.323240477...
# 7          50.0  (POLYGON ((1478476.569951459 6909271.81035307,...
# 8          42.0  (POLYGON ((1497603.484859558 6894118.055661174...
# 9          57.5  (POLYGON ((1498860.727188577 6918619.463303565...

# %%
#Câu 16
df.plot(column = 'district_group')

# %%
#Câu 17
df['median_price'].mean()
# Out:
# 43.76688405797101

# %%
#Câu 18
df.plot(column = 'district_group', figsize=(15, 15), scheme='Quantiles', k = 4, legend=True)

# %%
#Câu 19
import folium
import pandas as pd
import geopandas as gpd
countries = gpd.read_file("zip://./data/ne_110m_admin_0_countries.zip")
hanoi = folium.Map([21.0228161,105.801944], zoom_start=10, tiles="OpenStreetMap")
folium.GeoJson(countries.to_json()).add_to(hanoi)
hanoi
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Câu 20
import pandas as pd
import geopandas as gpd
rivers = gpd.read_file("zip://./data/ne_50m_rivers_lake_centerlines.zip")
countries = gpd.read_file("zip://./data/ne_110m_admin_0_countries.zip")
amazon = rivers[rivers['name'] == 'Amazonas'].geometry.squeeze()
countries[countries.crosses(amazon)]
# Out:
#     iso_a3      name      continent      pop_est  gdp_md_est  \
# 22     BRA    Brazil  South America  207353391.0   3081000.0
# 35     COL  Colombia  South America   47698524.0    688000.0
# 124    PER      Peru  South America   31036656.0    410400.0
#
#                                               geometry
# 22   POLYGON ((-57.625133429583 -30.21629485445423,...
# 35   POLYGON ((-66.87632585312258 1.253360500489336...
# 124  POLYGON ((-69.52967810736496 -10.9517343075021...
